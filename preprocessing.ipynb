# %%
#%pip install pandas

# %%
#%pip install numpy

# %%
#sklearn
#%pip install scikit-learn

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Lecture Notes/Degree/Sem 8/TCI - Computational Intelligence/new_project/smart-bin-sensor-fill-levels.csv")

# %%
df.head()
# Out:
#     bin_id  sensor_id  reading_id             timestamp  fill_level_percent  \
# 0  BIN-001  SNSR-1001  READ-00001  2024-06-03T07:34:15Z                12.3
# 1  BIN-002  SNSR-1002  READ-00002  2024-06-03T09:21:47Z                69.4
# 2  BIN-003  SNSR-1003  READ-00003  2024-06-03T11:10:32Z                95.1
# 3  BIN-004  SNSR-1004  READ-00004  2024-06-03T13:58:06Z                 8.6
# 4  BIN-005  SNSR-1005  READ-00005  2024-06-03T15:46:51Z                46.2
#
#     bin_type  location_latitude  location_longitude     address_street  \
# 0    general            40.7128            -74.0060       123 Broadway
# 1  recycling            51.5074             -0.1278     456 Piccadilly
# 2    organic            35.6895            139.6917        789 Shibuya
# 3  hazardous            52.5200             13.4050  23 Alexanderplatz
# 4      other           -33.8688            151.2093       55 George St
#
#   address_city address_state address_postal_code address_country  \
# 0     New York            NY               10007             USA
# 1       London       England             W1J 9HS              UK
# 2        Tokyo         Tokyo            150-0002           Japan
# 3       Berlin            BE               10178         Germany
# 4       Sydney           NSW                2000       Australia
#
#    battery_level_percent      bin_status  overflow_alert
# 0                   83.5          active           False
# 1                   61.2          active           False
# 2                   17.8     maintenance            True
# 3                   13.4  out_of_service           False
# 4                   58.7          active           False

# %%
#check for null values
print(df.isnull().sum())
# Out:
# bin_id                   0
# sensor_id                0
# reading_id               0
# timestamp                0
# fill_level_percent       0
# bin_type                 0
# location_latitude        0
# location_longitude       0
# address_street           3
# address_city             0
# address_state            0
# address_postal_code      0
# address_country          0
# battery_level_percent    0
# bin_status               0
# overflow_alert           0
# dtype: int64

# %%
#drop rows with null values
df = df.dropna()

# %%
#convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], format='mixed', utc=True)

# %%
print(df['timestamp'].head())
# Out:
# 0   2024-06-03 07:34:15+00:00
# 1   2024-06-03 09:21:47+00:00
# 2   2024-06-03 11:10:32+00:00
# 3   2024-06-03 13:58:06+00:00
# 4   2024-06-03 15:46:51+00:00
# Name: timestamp, dtype: datetime64[us, UTC]

# %%
df = df.sort_values(by=['bin_id', 'timestamp'])

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# In this part, we will convert categorical values to numerical values, and drop unnecessary columns.
# We also combined some columns to create useful entries.

# %%
#convert timestamp to hours since last reading for each bin
latest_time = df['timestamp'].max()

df['time_since_last_reading'] = (
    latest_time - df['timestamp']
).dt.total_seconds() / 3600

# %%
df.head()
# Out:
#     bin_id  sensor_id  reading_id                 timestamp  \
# 0  BIN-001  SNSR-1001  READ-00001 2024-06-03 07:34:15+00:00
# 1  BIN-002  SNSR-1002  READ-00002 2024-06-03 09:21:47+00:00
# 2  BIN-003  SNSR-1003  READ-00003 2024-06-03 11:10:32+00:00
# 3  BIN-004  SNSR-1004  READ-00004 2024-06-03 13:58:06+00:00
# 4  BIN-005  SNSR-1005  READ-00005 2024-06-03 15:46:51+00:00
#
#    fill_level_percent   bin_type  location_latitude  location_longitude  \
# 0                12.3    general            40.7128            -74.0060
# 1                69.4  recycling            51.5074             -0.1278
# 2                95.1    organic            35.6895            139.6917
# 3                 8.6  hazardous            52.5200             13.4050
# 4                46.2      other           -33.8688            151.2093
#
#       address_street address_city address_state address_postal_code  \
# 0       123 Broadway     New York            NY               10007
# 1     456 Piccadilly       London       England             W1J 9HS
# 2        789 Shibuya        Tokyo         Tokyo            150-0002
# 3  23 Alexanderplatz       Berlin            BE               10178
# 4       55 George St       Sydney           NSW                2000
#
#   address_country  battery_level_percent      bin_status  overflow_alert  \
# 0             USA                   83.5          active           False
# 1              UK                   61.2          active           False
# 2           Japan                   17.8     maintenance            True
# 3         Germany                   13.4  out_of_service           False
# 4       Australia                   58.7          active           False
#
#    time_since_last_reading
# 0                71.919444
# 1                70.127222
# 2                68.314722
# 3                65.521944
# 4                63.709444

# %%
#normalize 'time_since_last_reading' feature
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['time_since_last_reading_norm'] = scaler.fit_transform(
    df[['time_since_last_reading']]
)

# %%
df['bin_status'].unique()
# Out:
# <StringArray>
# ['active', 'maintenance', 'out_of_service']
# Length: 3, dtype: str

# %%
#encode bin_status
df['bin_status_encoded'] = df['bin_status'].map({'out_of_service': 0, 'active': 1, 'maintenance': 2})

# %%
df.head()
# Out:
#     bin_id  sensor_id  reading_id                 timestamp  \
# 0  BIN-001  SNSR-1001  READ-00001 2024-06-03 07:34:15+00:00
# 1  BIN-002  SNSR-1002  READ-00002 2024-06-03 09:21:47+00:00
# 2  BIN-003  SNSR-1003  READ-00003 2024-06-03 11:10:32+00:00
# 3  BIN-004  SNSR-1004  READ-00004 2024-06-03 13:58:06+00:00
# 4  BIN-005  SNSR-1005  READ-00005 2024-06-03 15:46:51+00:00
#
#    fill_level_percent   bin_type  location_latitude  location_longitude  \
# 0                12.3    general            40.7128            -74.0060
# 1                69.4  recycling            51.5074             -0.1278
# 2                95.1    organic            35.6895            139.6917
# 3                 8.6  hazardous            52.5200             13.4050
# 4                46.2      other           -33.8688            151.2093
#
#       address_street address_city address_state address_postal_code  \
# 0       123 Broadway     New York            NY               10007
# 1     456 Piccadilly       London       England             W1J 9HS
# 2        789 Shibuya        Tokyo         Tokyo            150-0002
# 3  23 Alexanderplatz       Berlin            BE               10178
# 4       55 George St       Sydney           NSW                2000
#
#   address_country  battery_level_percent      bin_status  overflow_alert  \
# 0             USA                   83.5          active           False
# 1              UK                   61.2          active           False
# 2           Japan                   17.8     maintenance            True
# 3         Germany                   13.4  out_of_service           False
# 4       Australia                   58.7          active           False
#
#    time_since_last_reading  time_since_last_reading_norm  bin_status_encoded
# 0                71.919444                      0.166294                   1
# 1                70.127222                      0.162150                   1
# 2                68.314722                      0.157959                   2
# 3                65.521944                      0.151501                   0
# 4                63.709444                      0.147310                   1

# %%
df['overflow_alert'].unique()
# Out:
# array([False,  True])

# %%
df['overflow_alert'] = df['overflow_alert'].astype(int)
df.head()
# Out:
#     bin_id  sensor_id  reading_id                 timestamp  \
# 0  BIN-001  SNSR-1001  READ-00001 2024-06-03 07:34:15+00:00
# 1  BIN-002  SNSR-1002  READ-00002 2024-06-03 09:21:47+00:00
# 2  BIN-003  SNSR-1003  READ-00003 2024-06-03 11:10:32+00:00
# 3  BIN-004  SNSR-1004  READ-00004 2024-06-03 13:58:06+00:00
# 4  BIN-005  SNSR-1005  READ-00005 2024-06-03 15:46:51+00:00
#
#    fill_level_percent   bin_type  location_latitude  location_longitude  \
# 0                12.3    general            40.7128            -74.0060
# 1                69.4  recycling            51.5074             -0.1278
# 2                95.1    organic            35.6895            139.6917
# 3                 8.6  hazardous            52.5200             13.4050
# 4                46.2      other           -33.8688            151.2093
#
#       address_street address_city address_state address_postal_code  \
# 0       123 Broadway     New York            NY               10007
# 1     456 Piccadilly       London       England             W1J 9HS
# 2        789 Shibuya        Tokyo         Tokyo            150-0002
# 3  23 Alexanderplatz       Berlin            BE               10178
# 4       55 George St       Sydney           NSW                2000
#
#   address_country  battery_level_percent      bin_status  overflow_alert  \
# 0             USA                   83.5          active               0
# 1              UK                   61.2          active               0
# 2           Japan                   17.8     maintenance               1
# 3         Germany                   13.4  out_of_service               0
# 4       Australia                   58.7          active               0
#
#    time_since_last_reading  time_since_last_reading_norm  bin_status_encoded
# 0                71.919444                      0.166294                   1
# 1                70.127222                      0.162150                   1
# 2                68.314722                      0.157959                   2
# 3                65.521944                      0.151501                   0
# 4                63.709444                      0.147310                   1

# %%
df['bin_type'].unique()
# Out:
# <StringArray>
# ['general', 'recycling', 'organic', 'hazardous', 'other']
# Length: 5, dtype: str

# %%
#drop unnecessary columns
df = df.drop(columns=['sensor_id', 'reading_id', 'timestamp', 'bin_type', 'location_longitude', 'location_latitude', 'address_street', 'address_city', 'address_state', 'address_postal_code', 'address_country', 'time_since_last_reading', 'bin_status'])

# %%
#assign priority labels based on fill_level_percent and overflow_alert
def assign_priority(row):
    if row['overflow_alert'] == 1 or row['fill_level_percent'] >= 85:
        return 2  # High
    elif row['fill_level_percent'] >= 60:
        return 1  # Medium
    else:
        return 0  # Low

df['priority_label'] = df.apply(assign_priority, axis=1)

# %%
df.head()
# Out:
#     bin_id  fill_level_percent  battery_level_percent  overflow_alert  \
# 0  BIN-001                12.3                   83.5               0
# 1  BIN-002                69.4                   61.2               0
# 2  BIN-003                95.1                   17.8               1
# 3  BIN-004                 8.6                   13.4               0
# 4  BIN-005                46.2                   58.7               0
#
#    time_since_last_reading_norm  bin_status_encoded  priority_label
# 0                      0.166294                   1               0
# 1                      0.162150                   1               1
# 2                      0.157959                   2               2
# 3                      0.151501                   0               0
# 4                      0.147310                   1               0

# %% [markdown]
# Finalize features that is used by all models

# %%
continuous_features = [
    'fill_level_percent',
    'battery_level_percent',
    'time_since_last_reading_norm'
]

categorical_features = [
    'overflow_alert',
    'bin_status_encoded'
]

bin_number = [
    'bin_id'
]

all_features = continuous_features + categorical_features + bin_number

# %%
X = df[all_features]
y = df['priority_label']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_cont_scaled = pd.DataFrame(
    scaler.fit_transform(X[continuous_features]),
    columns=continuous_features,
    index=X.index
)

# %%
X_final = pd.concat(
    [X_cont_scaled, X[categorical_features], X[bin_number]],
    axis=1
)

# %%
df.head()
# Out:
#     bin_id  fill_level_percent  battery_level_percent  overflow_alert  \
# 0  BIN-001                12.3                   83.5               0
# 1  BIN-002                69.4                   61.2               0
# 2  BIN-003                95.1                   17.8               1
# 3  BIN-004                 8.6                   13.4               0
# 4  BIN-005                46.2                   58.7               0
#
#    time_since_last_reading_norm  bin_status_encoded  priority_label
# 0                      0.166294                   1               0
# 1                      0.162150                   1               1
# 2                      0.157959                   2               2
# 3                      0.151501                   0               0
# 4                      0.147310                   1               0

# %%
#convert cleaned data to csv
cleaned_data = pd.concat([X_final, y], axis=1)
cleaned_data.to_csv("cleaned_smart_bin_data.csv", index=False)
